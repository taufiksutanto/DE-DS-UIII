# %% [markdown]
# <center><h2><strong><font color="blue"> Data Engineering for Data Science - Week 05</font></strong></h2></center>
#
# <center><img alt="" src="images/cover.png" style="height: 600px;"/></center>
#
# <center><h2><strong><font color="blue">DEDS-04: Relational Databases & SQL Fundamentals</font></strong></h2></center>
#
# <b><center><h3>(C) Taufik Sutanto</h3></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Outline</font></strong></h2></center>
#
# **Topics**:
#
# * DBMS Architecture (MySQL~MariaDB).
# * DDL (Create, Alter, Drop) vs. DML (Select, Insert, Update, Delete).
# * Advanced Selection: Joins (Inner, Left, Right, Full), Aggregations, and Window Functions.
#
# **Lab**:
# * Spin up a local MariaDB instance and query a sample research dataset.

# %% [markdown]
# <center><h2><strong><font color="blue">Prologue ~ Various Data Storage Solutions</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/Various-dataStorage-solutions.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">The (Hidden) Danger in Using Flat File</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/Various-dataStorage-solutions.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">The Rationale for REST APIs and Automation in Research</font></strong></h2></center>
#
# As data engineers, we must move beyond flat files (CSVs, Excel) toward robust storage systems. This module explores why Relational Database Management Systems (RDBMS) and Structured Query Language (SQL) are the industry standard for high-integrity research.
#
# <center><img alt="" src="images/deds-04/Motovation-Database.png" style="height: 600px;"/></center>
#
# ### 1. The Limitation of "Flat-File" Research
# Most researchers start by storing data in spreadsheets. While convenient, this "flat" approach fails as complexity increases due to:
# * **Data Redundancy**: Repeating the same information (e.g., student names) across 1,000 rows leads to massive file sizes and update errors.
# * **Integrity Risks**: Spreadsheets do not enforce "types." One can accidentally enter a string in a "Salary" column, breaking downstream analysis.
# * **Concurrency Issues**: If two researchers edit the same Excel file simultaneously, data loss is almost certain.
# * **Query Inefficiency**: Finding a specific record in a 10GB CSV file requires loading the entire file into memory—a highly unscalable process.

# %% [markdown]
# ### 2. Real-World Case Studies: The Database Advantage
#
# **Case A: Genomic Research Repositories**
# Genomic data involves billions of sequences and complex metadata. Projects like Ensembl use relational databases to link DNA sequences to specific genes, species, and clinical papers.
# * **The Rationale**: Researchers need to join millions of rows across disparate tables instantly without manual "VLOOKUPs."
# * **Outcome**: Precise, high-speed data retrieval that powers modern medicine.
#
# **Case B: Financial Transparency and Auditing**
# Central banks and financial institutions track millions of daily transactions. Using SQL allows them to enforce ACID properties (Atomicity, Consistency, Isolation, Durability).
# * **The Rationale**: If a transaction fails halfway, the database rolls back to the previous state, preventing "ghost money" errors.
# * **Outcome**: Guaranteed mathematical truth in financial records.
#
# **Case C: Large-Scale Social Surveys (The Census)**
# National census data involves complex relationships between households, individuals, and geographic regions. Relational databases allow researchers to query specific demographics across regions without duplicating person-level data.
# * **The Rationale**: Maintaining a "Single Source of Truth" where an address change in one table reflects across all linked records.
# * **Outcome**: Drastic reduction in data entry errors and storage costs.

# %% [markdown]
# ### 3. Why SQL is the Language of Data Engineering
# SQL (Structured Query Language) is a declarative language, meaning you tell the system what data you want, not how to fetch it.
# * **Declarative Power**: A single SQL line can replace 50 lines of complex Python loops.
# * **Standardization**: Whether you use PostgreSQL, MySQL, or BigQuery, the core SQL syntax remains remarkably consistent.
# * **Data-Code Separation**: Keeping data in a database and logic in Python scripts (Week 2) ensures that a bug in your code cannot accidentally delete your primary data source.
#
# ### 4. Reputable References for Further Reading
# To deepen your understanding of why databases are critical for scientific infrastructure:
#
# > ***Relational databases provide the structure, safety, and speed required for production-grade research. By mastering SQL, you transition from "browsing files" to "architecting information systems***."
#
# ### Some Reference
# 1. Codd, E. F. (1970). A Relational Model of Data for Large Shared Data Banks. Communications of the ACM. (The foundational paper that invented the relational model).
# 2. Silberschatz, A., Korth, H. F., & Sudarshan, S. (2019). Database System Concepts. McGraw-Hill. (The definitive textbook for database architecture).
# 3. White, T. (2015). Hadoop: The Definitive Guide. O'Reilly Media. (Discusses the evolution from RDBMS to Big Data systems).

# %% [markdown]
# <center><h2><strong><font color="blue">ACID VS BASE concept in Databases</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/ACID-vs-BASE-Databases.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">The Big 4 SQL Databases: MsySQL, PosGresql, Oracle, Microsoft SQL Server</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/SQL-Databases-The-Big-04.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">MySQL vs MySQL????</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/mariaDB-vs-MySQL.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Installing MariaDB (Windows)</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/installing-MariaDB-Windows.png" style="height: 600px;"/></center>

# %% [markdown]
# # Database and Table Naming Conventions/Recommendations
#
# <center><img alt="" src="images/deds-04/database-table-naming-conventions.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Schema Definition and Data Entry via phpMyAdmin</font></strong></h2></center>
#
# A robust data architecture begins with precise schema definition. This module outlines the systematic process of initializing databases and tables using the phpMyAdmin graphical interface, while emphasizing the critical role of data typing in MariaDB.
#
# ## 1. Fundamental MariaDB Data Types
#
# Relational integrity depends on the selection of appropriate data types. Choosing the correct format optimizes storage and prevents data corruption:
#
# ### Numeric Types:
#
# * **INT**: Standard integers for counts or IDs.
# * **DECIMAL**: Necessary for financial or high-precision research data.
# * **FLOAT/DOUBLE**: Used for approximate numerical values in scientific modeling.
#
# ### String Types:
# * **VARCHAR(n)**: Variable-length strings (e.g., names or emails). Highly efficient.
# * **TEXT**: Reserved for large blocks of descriptive research notes.
# * **CHAR**: Fixed-length strings (e.g., ISO country codes).
#
# ### Temporal Types:
# * DATE: Stores YYYY-MM-DD formats.
# * DATETIME: Captures both date and time.
# * TIMESTAMP: Automatically updates during record modification; ideal for audit trails.

# %% [markdown]
# ## 2. Systematic Database Initialization
# The creation of a database container is the first step in project setup:
# * **Access**: Open the dashboard at localhost/phpmyadmin.
# * **Navigation**: Select the "New" option in the left-hand sidebar.
# * **Naming**: Enter a descriptive, lowercase name (e.g., uiii_research_db).
# * **Collation**: Choose utf8mb4_general_ci to ensure compatibility with diverse international character sets.
# * **Execution**: Click "Create".
#
# ## 3. Structural Table Definition
# Once the database is active, you must define the internal table structures:
#
# * **Identity**: Assign a pluralized table name (e.g., climate_sensors).
# * **Field Definition**: Define column names (e.g., sensor_id, location, reading_value).
# * Assign the corresponding Data Types and Lengths.
# * Primary Key (PK): Every table "must" have a unique identifier. Set the id column to PRIMARY and enable A_I (Auto-increment) to automate indexing.
# * Persistence: Click "Save" to finalize the schema.
#
# ### 4. Manual Data Entry (DML)
# For initial testing or small datasets, use the graphical insertion tool:
# * Selection: Navigate to your table and click the "Insert" tab.
# * Input: Populate the fields with research data.
# * Note on Auto-increment: Leave the id field empty; the system generates this value automatically.
# * Finalization: Click "Go". The system will execute an INSERT statement and display the success message.
#
# > *PhpMyAdmin serves as an excellent validation tool for schema logic. However, practitioners should remember that professional data engineering favors SQL scripts (DDL) for reproducibility. Use this GUI to verify that your data types and constraints behave as expected before automating via Python*.

# %% [markdown]
# <center><h2><strong><font color="blue">Introduction to PhPMyAdmin</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/introduction-to-PhpMyadmin.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><img alt="" src="images/deds-04/schema-definition-data-entry.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Relational Logic — Keys, Relationships, and Indexing</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/DB-relational-logics-keys-index.png" style="height: 600px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">MariaDB/MySQL via Python</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-04/mariaDB-from-python.png" style="height: 600px;"/></center>

# %% [markdown]
# ## Install The Python Database "Driver"/Connector

# %%
# !pip install mysql-connector-python --q

# %% [markdown]
# ### Step 1: Database Connection
#
# The first phase involves establishing a connection to the server (without specifying a database).

# %%
import mysql.connector

# Connect to the server
try:
    db = mysql.connector.connect(
        host="localhost",
        user="root",
        password="") # Default XAMPP configuration
    con = db.cursor()
    print("Connected to the Database server.")
except Exception as err_:
    print("Connection to the Database server failed:")
    print(err_)
# Out:
# Connected to the Database server.

# %% [markdown]
# ### Step 2: Create the Database

# %%
# Create Database
con.execute("CREATE DATABASE IF NOT EXISTS uiii_der")

# Switch to the new database
con.execute("USE uiii_der")
"Database Created" # you may verify using PhPMyAdmin
# Out:
# 'Database Created'

# %% [markdown]
# ## Create Table (DDL)

# %%
con.execute("""
    CREATE TABLE IF NOT EXISTS experimental_results (
        id INT AUTO_INCREMENT PRIMARY KEY,
        sample_name VARCHAR(255),
        metric_value FLOAT,
        timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
""")
print("Table created successfully.")
# Out:
# Table created successfully.

# %% [markdown]
# ## Step 2: Data Ingestion (Insert)
# To persist research observations, we perform Data Ingestion. It is a professional standard to use Parameterized Queries to prevent SQL injection vulnerabilities.

# %%
# Define data to be inserted
val = ("Sample_A", 98.6)
sql = "INSERT INTO experimental_results (sample_name, metric_value) VALUES (%s, %s)"

# Execute and Commit
con.execute(sql, val)
db.commit() # Mandatory for data modification

print(f"Record inserted. ID: {cursor.lastrowid}")
# Out:
# Record inserted. ID: 1

# %% [markdown]
# ## Data Retrieval (Read)
# The final phase involves querying the database to fetch records for analysis. The fetchall() method retrieves all rows matching the criteria.

# %%
# Define selection query
qry = "SELECT * FROM experimental_results"
con.execute(qry)

# Fetch and display results
rows = con.fetchall()

print("Current Records:")
for row in rows:
    print(row)

# Release resources
con.close()
db.close()
# Out:
# Current Records:
# (1, 'Sample_A', 98.6, datetime.datetime(2026, 4, 13, 18, 59, 34))

# %%
type(row)
# Out:
# tuple

# %% [markdown]
# ### Why tuple?
#
# ### Can we load data to Dataframe?

# %%
# Best Practice; use a function to connect to our database
def connect(host="localhost", user="root", password="", db=""):
    try:
        db = mysql.connector.connect(
            host=host,
            user=user,
            password="",
            database=db)
        con = db.cursor()
        print("Connected to the Database server.")
        return db, con
    except Exception as err_:
        print("Connection to the Database server failed:")
        print(err_)

# %%
import warnings; warnings.simplefilter('ignore')
import pandas as pd

db, con = connect(host="localhost", user="root", password="", db="uiii_der")
qry = "SELECT * FROM experimental_results"
df = pd.read_sql(qry, db) # pay attention we are using db, and not "con". Pandas recommend using alchemy SQL connection
df.head()
# Out:
# Connected to the Database server.
#    id sample_name  metric_value           timestamp
# 0   1    Sample_A          98.6 2026-04-13 18:59:34

# %% [markdown]
# ## Stop and Practice with the following Exercise
#
# <center><img alt="" src="images/stop-exercise-learn.jpg" style="height: 320px;"/></center>

# %% [markdown]
# ## Exercise: A simple case study ~ Universal University Management System
#
# This exercise focuses on implementing a relational database for a universal academic context. It requires students to apply principles of referential integrity, normalization, and standard naming conventions. The **Global Student Registry** requires a centralized database to manage academic records. The objective is to replace fragmented spreadsheets with a structured system that links students, instructors, and courses. This architecture must ensure that data remains consistent and eliminates redundancy.
#
# ## 1. Technical Specifications
# ### Naming Standards
# Strict adherence to professional naming conventions is mandatory:
# * **snake_case:** Use lowercase with underscores for all identifiers.
# * **Plural Table Names:** Use names like `students` or `instructors`.
# * **Primary Keys:** Every table must use `id` as the primary identifier.
# * **Foreign Keys:** Use the format `<referenced_table_singular>_id` (e.g., `student_id`).
#
# ## 2. Database Schema Architecture
# | Table Name | Description | Key Columns |
# | :--- | :--- | :--- |
# | `instructors` | Stores details of academic staff. | `id`, `full_name`, `email` |
# | `courses` | Catalog of subjects offered. | `id`, `title`, `instructor_id` (FK) |
# | `students` | Profiles of registered students. | `id`, `full_name`, `country_origin` |
# | `enrollments` | Junction table managing grades. | `id`, `student_id` (FK), `course_id` (FK), `grade` |
#
# ## 3. Laboratory Tasks
# ### Task 1: Schema Definition (DDL)
# Initialize a database named `university_registry_db`. Construct the four tables defined in the schema architecture. Ensure all `id` columns use `INT AUTO_INCREMENT` and establish formal **Foreign Key** constraints to maintain data integrity.
#
# ### Task 2: Data Population (DML)
# Insert the following records to validate the schema:
# * **2 Instructors** representing different academic departments.
# * **3 Courses** assigned to those instructors.
# * **5 Students** from various international backgrounds.
# * **10 Enrollments** assigning numerical grades (e.g., 0.0 to 4.0) to students.
#
# ### Task 3: Programmatic Integration (Python)
# Develop a Python script to perform the following operations:
# 1. **Connection:** Connect to MariaDB using credentials from a `.env` file.
# 2. **Data Extraction:** Query the database for all students with a grade exceeding 3.5.
# 3. **Analysis:** Load the results into a **Pandas DataFrame** for verification.

# %% [markdown]
# <center><img alt="" src="images/deds-04/DB-caseStudy-univ-management.png" style="height: 480px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Implementation of Relational Logic and Connectivity</font></strong></h2></center>
#
# The establishment of Relational Logic and Connectivity is the cornerstone of professional database management. This process involves defining the mathematical relationships between entities and constructing a programmatic bridge for data transmission.
#
# ### 1. Defining Relational Logic (DDL)
# Relational logic is enforced through the use of Primary Keys (PK) and Foreign Keys (FK). This ensures that every record is unique and that child records always point to a valid parent.
#
# a. Primary and Foreign Keys
# A Primary Key uniquely identifies a row, while a Foreign Key references a Primary Key in another table to create a link.
#
# ### Relational Logic and Connectivity
# In the previous case study, the system must support the following logical links:
# * **Instructor to Courses:** Each instructor can lead multiple courses (**One-to-Many / 1:N**).
# * **Student to Enrollments:** Each student can have multiple enrollment records (**One-to-Many / 1:N**).
# * **Course to Enrollments:** Each course can accommodate many student enrollments (**One-to-Many / 1:N**).
# * **Student to Courses:** This **Many-to-Many (M:N)** relationship is resolved via the `enrollments` junction table.
#
# ```sql
#
# -- Create the parent table
# CREATE TABLE students (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     full_name VARCHAR(255) NOT NULL,
#     country_origin VARCHAR(255) NOT NULL
# );
#
# CREATE TABLE instructors (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     full_name VARCHAR(255) NOT NULL
# );
#
# -- Create the child table (1:N Relationship)
# CREATE TABLE courses (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     title VARCHAR(255) NOT NULL,
#     instructor_id INT,
#     CONSTRAINT fk_instructor
#         FOREIGN KEY (instructor_id) REFERENCES instructors(id)
#         ON DELETE CASCADE
# );
# ```

# %% [markdown]
# ### Junction Tables for Many-to-Many (M:N) Relationships
# When multiple students enroll in multiple courses, a Junction Table is required to resolve the relationship.
#
# ```sql
# CREATE TABLE enrollments (
#     id INT AUTO_INCREMENT PRIMARY KEY,
#     student_id INT,
#     course_id INT,
#     grade DECIMAL(3, 2),
#     FOREIGN KEY (student_id) REFERENCES students(id),
#     FOREIGN KEY (course_id) REFERENCES courses(id)
# );
# ```

# %% [markdown]
# ### Click "Designer" tab in phpMyadmin to see the result.

# %%
# DDL (Create, Alter, Drop)

# %%
# DML (Select, Insert, Update, Delete).

# %%
# Change security parameters

# %%
# Create username and set roles

# %%
# Database Engines

# %%
# Encodings in string variables

# %%
# Export-Import Data using SQL format

# %%
# my.ini

# %%
# Practice ... insert data from youtube to database

# %%
# Advanced Selection: Joins (Inner, Left, Right, Full),

# %%
# Aggregations

# %%
# Window Functions

# %%
# Lab Practice ==> API to database

# %% [markdown]
# <center><h2><strong><font color="blue">End of Module</font></strong></h2></center>
#
# <center><img alt="" src="images/meme-cartoon/database-meme-access-excel.jpeg" style="height: 480px;"/></center>
