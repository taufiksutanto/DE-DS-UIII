# %% [markdown]
# <center><h2><strong><font color="blue"> Data Engineering for Data Science</font></strong></h2></center>
#
# <center><img alt="" src="images/cover.png" style="height: 360px;"/></center>
#
# <center><h2><strong><font color="blue">DEDS-01: Introduction to Git-GitHub</font></strong></h2></center>
#
# <b><center><h3>(C) Taufik Sutanto</h3></center>

# %% [markdown]
# ## Outline
#
# * Introduction to Git and GitHub
# * Installation and Setup
# * Terminologies
# * Creating/Clone Repositories, Visibility, & Collaborators
# * Understanding Basic Licenses
# * Understanding GitIgnores
# * Understanding Markdown in Git
# * Basic Git Command (Push, Pull, Commit, Showcase)
# * Branch, Merge, undo commit, ammend
# * Cherry Pick & Re-order
#
# **Exercise:**
# > Setup a GitHub repository and collaborate on a simple script with a partner.

# %% [markdown]
# <center><h2><strong><font color="blue">What is Git? GitHub? GitLab?</font></strong></h2></center>
#
# **Git** is a version control system that allows multiple people to work on a project without overwriting each other's changes. It's like a time machine: you can go back to the past to see what your project looked like at any point in the history. https://git-scm.com/about
#
# **GitHub** is a hosting service for git repositories. It's a place where developers can store their projects and star, comment and explore other people's projects. https://github.com/
#
# **GitHub** alternative to GitHub https://about.gitlab.com/
#
# > **Which one to choose**?
#
# <center><img alt="" src="images/deds-01/git-logo.png" style="height: 100px;"/><img alt="" src="images/deds-01/gitHub-logo.png" style="height: 100px;"/><img alt="" src="images/deds-01/gitLab-logo.png" style="height: 100px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Why Git? (The Motivation)</font></strong></h2></center>
#
# Good practice in programming project management requires a version control system.
# Old school techniques are usually bad.
#
# * Version filenames is a disaster.
#      - mythesis_v1.tex, mythesis_v2.tex, mythesis_last_v3.tex
#      - creates clutter
#      - Filenames rarely contain information other than chronology
#      - Parallel independent changes super hard to keep track of
#      - Did you finally notice a problem in v119 that has been around for a while, but you have no idea where the error was introduced?
#
# * Sharing files with others is a disaster.
#     - Emailing files is **** — only magnifies the problems above
#     - Track changes feature Google Docs or Word — not so useful for anything complex
#
# * Disaster recover is a disaster.
#     - Oh ****! Did I just overwrite all my work from last night??!!!?
#
# <center><img alt="" src="images/meme-cartoon/filename-nightmare-meme.png" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Installation and Setup</font></strong></h2></center>
#
# 1. go to https://github.com/
# 2. Register/Login (using Google account is recommended)
# 3. Download and install GitHub Desktop (recommended) https://desktop.github.com/download/ or Git CLI (if you want to use command lines) https://cli.github.com/
# 4. Prepare GitHub local folder (e.g. **C:\GitHub**)
# 5. Open GitHub application and sign-in using the same account as email account in No 02
# 6. Git(Hub) is ready

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('N6vPzWkPN_Y', width=800, height=300)

# %% [markdown]
# <center><h2><strong><font color="blue">Creating Your First Repository</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-01/new-repository.jpg" style="height: 360px;"/></center>
#
# * A repository is usually used to organize a single project.
# * Repositories can contain folders and files, images, videos, spreadsheets, and data sets – anything your project needs.
# * Often, repositories include a README file, a file with information about your project written in the plain text Markdown language. A Markdown language cheat sheet: https://www.markdownguide.org/cheat-sheet/

# %% [markdown]
# <center><h2><strong><font color="blue">Publish Repository</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-01/publish-repository.jpg" style="height: 360px;"/></center>
#
# * Private VS Public
# * Check your repository on https://github.com/YourGitHubAccountName

# %% [markdown]
# <center><h2><strong><font color="blue">Introduction to Markdown for GitHub README Files</font></strong></h2></center>
#
# Markdown is a lightweight markup language designed to enable authors to write structured documents using plain text syntax (similar to WhatsApp text Commands). It is widely used in software development environments because it provides a simple method to format documentation without requiring complex formatting tools.
#
# # Project Title
# ## Installation
# ### Usage
# #### Configuration
# ===================
#
# **bold text**
# *italic text*
# `inline code`
#
# ====================
#
# - Unordered
# - List
# - in MarkDown
#
# ===================
#
# 1. Numbering
# 2. is
# 3. straight forward
#
# =====================
#
# [Visit GitHub](https://github.com)
#
# ====================
#
# ![Project image](images/deds-01//gitHub-logo.png)
#
# ====================
# | Language | Type |
# |---------|------|
# | Python | Interpreted |
# | C++ | Compiled |
# | JavaScript | Interpreted |
#
# ==================
#
# > This project is currently under development.
#
# =================
# - [x] Create repository
# - [x] Write README
# - [ ] Implement main features
#
# ==================
#
# ```python
# import numpy as np
#
# print("Hello, World!")

# %% [markdown]
# <center><h2><strong><font color="blue">Understanding GitIgnore</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-01/gitignore.jpg" style="height: 420px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Understanding GitAttributes</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-01/gitattributes.jpg" style="height: 420px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Understanding (Basic) License</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-01/Basic-License.jpg" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Private, Public, Collaborator</font></strong></h2></center>
#
# <center><img alt="" src="images/deds-01/git-private-public-collaborator.png" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Add, Clone, VS Fork (Repository)</font></strong></h2></center>
#
# * Clone this Course Repository https://github.com/taufiksutanto/DE-DS-UIII
#
# <center><img alt="" src="images/deds-01/git-add-clone-fork.jpg" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Push, Pull, Commit</font></strong></h2></center>
#
# * I will create a (public) demo repository for to work-on, I will call it "Git Demo"
# * Let's work on this repository
#
# <center><img alt="" src="images/deds-01/git-push-pull-commit.jpg" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Commit</font></strong></h2></center>
#
# * When you created a new branch in the previous step, GitHub brought you to the code page for your new readme-edits branch, which is a copy of main.
# * You can make and save changes to the files in your repository. On GitHub, saved changes are called commits.
# * Each commit has an associated commit message, which is a description tha captures the history of your changes so that other contributors can understand what you’ve done and why.

# %% [markdown]
# <center><h2><strong><font color="blue">Pull</font></strong></h2></center>
#
# * Now that you have changes in a branch off of main, you can open a pull request.
# * Pull requests are the heart of collaboration on GitHub. When you open a pull request, you’re proposing your changes and requesting that someone review and pull in your contribution and merge them into their branch. Pull requests show diffs, or differences, of the content from both branches. The changes, additions, and subtractions are shown in different colors.
# * As soon as you make a commit, you can open a pull request and start a discussion, even before the code is finished. By using GitHub’s @mention feature in your pull request message, you can ask for feedback from specific people or teams.

# %% [markdown]
# <center><h2><strong><font color="blue">Branches</font></strong></h2></center>
#
# * Branching lets you have different versions of a repository at one time.
# * Your repository has only one branch named main by default, but you can create additional branches off of main in your repository. You can use branches to have different versions of a project at one time. This is helpful when you want to add new features to a project without changing the main source of code.
# * The work done on different branches will not show up on the main branch until you merge it. You can use branches to experiment and make edits before committing them to main.
#
# <center><img alt="" src="images/deds-01/branch-git.png" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Branches and DAGs</font></strong></h2></center>
#
# ### A DAG is a directed acyclic graph linking together a sequence of tasks.
# * An Awesome Website to learn about Managing Git Branches: https://learngitbranching.js.org/
#
# <center><img alt="" src="images/deds-01/DAG_example.png" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Managing Branch</font></strong></h2></center>
#
# * https://docs.github.com/en/desktop/making-changes-in-a-branch/managing-branches-in-github-desktop
#
# <center><img alt="" src="images/deds-01/understanding-git-branch.jpg" style="height: 360px;"/></center>

# %% [markdown]
# <center><h2><strong><font color="blue">Managing Commits</font></strong></h2></center>
#
# * https://docs.github.com/en/desktop/managing-commits/options-for-managing-commits-in-github-desktop
#
# <center><img alt="" src="images/deds-01/git-commits.jpg" style="height: 420px;"/></center>

# %% [markdown]
# ## Starring and Watching Repositories
#
# GitHub provides features to help you keep track of repositories that you find interesting.
#
# - **Starring a Repository:** If you find a GitHub repository interesting or would like to follow it, you can star it. Starring a repository also shows appreciation to its maintainer for their work. Repositories that you star will be listed on your GitHub profile page.
#
# - **Watching a Repository:** If you want to get notified of all activity in a repository, you can 'Watch' it. This is particularly useful if you are contributing to a project and want to keep track of issues and pull requests.
#
# Starring and Watching can be done on the GitHub website, and doesn't require any bash commands.
#
# ## GitHub Issues and Discussions
#
# - **GitHub Issues:** GitHub Issues is a great way to keep track of tasks, enhancements, and bugs for your projects. They’re kind of like email, except they can be shared and discussed with the rest of your team. Issues are also searchable and can be organized with labels and milestones.
#
# - **GitHub Discussions:** Discussions is a collaborative communication forum for the community around an open source project. It is the place where the community can have open-ended conversations, ask for help, share ideas and engage with each other.
#
# Just like with Starring and Watching, working with Issues and Discussions is done on the GitHub website, and doesn't require any bash commands.
#
# ## Conclusion and Additional Resources
#
# Congratulations on completing this introduction to git and GitHub! You've covered a lot of ground, from basic commands to more complex tasks like branching and merging, and you've learned about some of the collaborative features of GitHub.
#
# Remember, git is a powerful tool for version control and collaboration. It may take some time to get used to, especially if you're new to programming, but it's a valuable skill that will benefit you in the long run.
#
# Remember, practice makes perfect. The more you use git and GitHub, the more comfortable you'll become. Happy coding!

# %% [markdown]
# <center><h2><strong><font color="blue">End of Module</font></strong></h2></center>
# <hr>
# <center><img alt="" src="images/meme-cartoon/git-meme-incase-fire.jpg" style="height: 360px;"/></center>
